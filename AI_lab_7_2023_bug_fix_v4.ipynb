# %% [markdown]
# ## A.I. Assignment 7
#
# ## Learning Goals
#
# By the end of this lab, you should be able to:
# * Get more familiar with computer vision concepts
# * Understand Convolutions
# * Understand and trainsimple models
# * Undertstand pooling and train convolutional model
#
#
# ### Task
#
# In the context of image processing, a kernel is a small matrix of numbers that is applied to an image to perform operations such as blurring, sharpening, edge detection, and more. The kernel is usually a square matrix with odd dimensions, such as 3x3 or 5x5.
#
# We will train simple models using liniear layers and non linear layers that we learned how to use in the previous labs and then train a convolutional neural network and compare the results

# %% [markdown]
# # Computer Vision Intro

# %% [markdown]
# [Computer vision](https://en.wikipedia.org/wiki/Computer_vision) is the art of teaching a computer to see.
#
# For example, it could involve building a model to classify whether a photo is of a cat or a dog ([binary classification](https://developers.google.com/machine-learning/glossary#binary-classification)).
#
# Or whether a photo is of a cat, dog or chicken ([multi-class classification](https://developers.google.com/machine-learning/glossary#multi-class-classification)).
#
# Or identifying where a car appears in a video frame ([object detection](https://en.wikipedia.org/wiki/Object_detection)).
#
# Or figuring out where different objects in an image can be separated ([panoptic segmentation](https://arxiv.org/abs/1801.00868)).
#
# ![example computer vision problems](https://raw.githubusercontent.com/mrdbourke/pytorch-deep-learning/main/images/03-computer-vision-problems.png)
# *Example computer vision problems for binary classification, multiclass classification, object detection and segmentation.*

# %% [markdown]
# ## What we're going to cover
#
# We're going to apply the PyTorch Workflow we've been learning in the past couple of sections to computer vision.
#
# ![a PyTorch workflow with a computer vision focus](https://raw.githubusercontent.com/mrdbourke/pytorch-deep-learning/main/images/03-pytorch-computer-vision-workflow.png)

# %% [markdown]
# ## Storing Images in PyTorch
#
# In PyTorch, images are typically stored as tensors, which are multi-dimensional arrays. For example, a grayscale image with dimensions 128 x 128 pixels would be represented as a tensor with shape (1, 128, 128), where the first dimension represents the number of color channels (in this case 1 for grayscale), and the remaining dimensions represent the height and width of the image.
#
# Similarly, a color image with dimensions 128 x 128 pixels would be represented as a tensor with shape (3, 128, 128), where the first dimension represents the number of color channels (in this case 3 for red, green, and blue), and the remaining dimensions represent the height and width of the image.

# %%
import torch
import torchvision
import matplotlib.pyplot as plt
from PIL import Image

# Load an image file into a PyTorch tensor
image = torchvision.io.read_image('corgi.jpg')

# %%
# Create a grid of images
grid = torchvision.utils.make_grid(image)

# Display the grid using matplotlib
plt.imshow(grid.permute(1, 2, 0))
plt.show()

# %% [markdown]
# ## Images in numpy

# %%
import numpy as np
# Load an image file into a Python array
image = Image.open('corgi.jpg')
image_array = np.array(image)

# Display the image using matplotlib
plt.imshow(image_array)
plt.show()

# %% [markdown]
# # What is a convolution ?

# %% [markdown]
# ## Problems with the Fully-connected nn
# ### Fully-Connected = What we did with linear layers and activations
# - Do you need to consider all the relations between the features?
# - Fully connected nn are big and so very computationally inefficient
# - They have so many parameters, and so overfit
# ## Main idea of CNN
# - Units are connected with only a few units from the previous layer
# - Units share weights
# ### Main Idea
# ![image.png](attachment:d1ec6271-1b0d-4e2b-be1c-d2dfaf92ab82.png)!
# ### Convolving operation
# ![image.png](attachment:f3729a09-18b1-4cb6-be3a-d72862c55340.png)!
# ### Resulting activation map
# ![image.png](attachment:bb966f2f-f3f5-4830-b640-5d16e4db6d25.png)!

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (8, 8)

# %%
images = torch.rand(10, 1, 28, 28)

# Build 6 conv. filters
conv_filters = nn.Conv2d(in_channels=1, out_channels=6, kernel_size=(3, 3), stride=1, padding=1)

# Convolve the image with the filters
output_feature = conv_filters(images)
print(output_feature.shape)
# Out:
# torch.Size([10, 6, 28, 28])

# %%
# Applying the convolution we get 6 filters

# %% [markdown]
# ## Let's apply the convolution on the corgi

# %%
# Load an image file into a PyTorch tensor
image = torchvision.io.read_image('corgi.jpg').float()

# Normalize the pixel values to be between 0 and 1
image /= 255.0

# %%
# Define a convolutional filter with 3 input channels, 10 output channels, and a kernel size of 3
conv_filter = nn.Conv2d(3, 10, kernel_size=3)

# %%
print(image.shape)
# Out:
# torch.Size([3, 334, 515])

# %%
output = conv_filter(image)

# %%
# Create a grid of images
grid = torchvision.utils.make_grid(output)
# Display the grid using matplotlib
plt.imshow(output.detach()[2]) # One 0 is the batch and one is the signal (RGB)
plt.show()

#This is just 1 random filter

# %%
# Ex 1: Look at some other channels

# %% [markdown]
# ## Computer vision libraries in PyTorch
#
# Before we get started writing code, let's talk about some PyTorch computer vision libraries you should be aware of.
#
# | PyTorch module | What does it do? |
# | ----- | ----- |
# | [`torchvision`](https://pytorch.org/vision/stable/index.html) | Contains datasets, model architectures and image transformations often used for computer vision problems. |
# | [`torchvision.datasets`](https://pytorch.org/vision/stable/datasets.html) | Here you'll find many example computer vision datasets for a range of problems from image classification, object detection, image captioning, video classification and more. It also contains [a series of base classes for making custom datasets](https://pytorch.org/vision/stable/datasets.html#base-classes-for-custom-datasets). |
# | [`torchvision.models`](https://pytorch.org/vision/stable/models.html) | This module contains well-performing and commonly used computer vision model architectures implemented in PyTorch, you can use these with your own problems. |
# | [`torchvision.transforms`](https://pytorch.org/vision/stable/transforms.html) | Often images need to be transformed (turned into numbers/processed/augmented) before being used with a model, common image transformations are found here. |
# | [`torch.utils.data.Dataset`](https://pytorch.org/docs/stable/data.html#torch.utils.data.Dataset) | Base dataset class for PyTorch.  |
# | [`torch.utils.data.DataLoader`](https://pytorch.org/docs/stable/data.html#module-torch.utils.data) | Creates a Python iteralbe over a dataset (created with `torch.utils.data.Dataset`). |
#
# > **Note:** The `torch.utils.data.Dataset` and `torch.utils.data.DataLoader` classes aren't only for computer vision in PyTorch, they are capable of dealing with many different types of data.
#
# Now we've covered some of the most important PyTorch computer vision libraries, let's import the relevant dependencies.

# %% [markdown]
# ## 1. Getting a dataset
#
# To begin working on a computer vision problem, let's get a computer vision dataset.
#
# We're going to start with FashionMNIST.
#
# MNIST stands for Modified National Institute of Standards and Technology.
#
# The [original MNIST dataset](https://en.wikipedia.org/wiki/MNIST_database) contains thousands of examples of handwritten digits (from 0 to 9) and was used to build computer vision models to identify numbers for postal services.
#
# [FashionMNIST](https://github.com/zalandoresearch/fashion-mnist), made by Zalando Research, is a similar setup.
#
# Except it contains grayscale images of 10 different kinds of clothing.
#
# ![example image of FashionMNIST](https://raw.githubusercontent.com/mrdbourke/pytorch-deep-learning/main/images/03-fashion-mnist-slide.png)
# *`torchvision.datasets` contains a lot of example datasets you can use to practice writing computer vision code on. FashionMNIST is one of those datasets. And since it has 10 different image classes (different types of clothing), it's a multi-class classification problem.*
#
# Later, we'll be building a computer vision neural network to identify the different styles of clothing in these images.
#
# PyTorch has a bunch of common computer vision datasets stored in `torchvision.datasets`.
#
# Including FashionMNIST in [`torchvision.datasets.FashionMNIST()`](https://pytorch.org/vision/main/generated/torchvision.datasets.FashionMNIST.html).
#
# To download it, we provide the following parameters:
# * `root: str` - which folder do you want to download the data to?
# * `train: Bool` - do you want the training or test split?
# * `download: Bool` - should the data be downloaded?
# * `transform: torchvision.transforms` - what transformations would you like to do on the data?
# * `target_transform` - you can transform the targets (labels) if you like too.
#
# Many other datasets in `torchvision` have these parameter options.

# %%
import torchvision
from torchvision import datasets
from torchvision.transforms import ToTensor

# Setup training data
train_data = datasets.FashionMNIST(
    root="data", # where to download data to?
    train=True, # get training data
    download=True, # download data if it doesn't exist on disk
    transform=ToTensor(), # images come as PIL format, we want to turn into Torch tensors
    target_transform=None # you can transform labels as well
)

# Setup testing data
test_data = datasets.FashionMNIST(
    root="data",
    train=False, # get test data
    download=True,
    transform=ToTensor()
)

# %%
# See first training sample
image, label = train_data[0]
image, label
# Out:
# (tensor([[[0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0039, 0.0000, 0.0000, 0.0510,
#            0.2863, 0.0000, 0.0000, 0.0039, 0.0157, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0039, 0.0039, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0118, 0.0000, 0.1412, 0.5333,
#            0.4980, 0.2431, 0.2118, 0.0000, 0.0000, 0.0000, 0.0039, 0.0118,
#            0.0157, 0.0000, 0.0000, 0.0118],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0235, 0.0000, 0.4000, 0.8000,
#            0.6902, 0.5255, 0.5647, 0.4824, 0.0902, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0471, 0.0392, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.6078, 0.9255,
#            0.8118, 0.6980, 0.4196, 0.6118, 0.6314, 0.4275, 0.2510, 0.0902,
#            0.3020, 0.5098, 0.2824, 0.0588],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0039, 0.0000, 0.2706, 0.8118, 0.8745,
#            0.8549, 0.8471, 0.8471, 0.6392, 0.4980, 0.4745, 0.4784, 0.5725,
#            0.5529, 0.3451, 0.6745, 0.2588],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0039, 0.0039, 0.0039, 0.0000, 0.7843, 0.9098, 0.9098,
#            0.9137, 0.8980, 0.8745, 0.8745, 0.8431, 0.8353, 0.6431, 0.4980,
#            0.4824, 0.7686, 0.8980, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.7176, 0.8824, 0.8471,
#            0.8745, 0.8941, 0.9216, 0.8902, 0.8784, 0.8706, 0.8784, 0.8667,
#            0.8745, 0.9608, 0.6784, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.7569, 0.8941, 0.8549,
#            0.8353, 0.7765, 0.7059, 0.8314, 0.8235, 0.8275, 0.8353, 0.8745,
#            0.8627, 0.9529, 0.7922, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0039, 0.0118, 0.0000, 0.0471, 0.8588, 0.8627, 0.8314,
#            0.8549, 0.7529, 0.6627, 0.8902, 0.8157, 0.8549, 0.8784, 0.8314,
#            0.8863, 0.7725, 0.8196, 0.2039],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0235, 0.0000, 0.3882, 0.9569, 0.8706, 0.8627,
#            0.8549, 0.7961, 0.7765, 0.8667, 0.8431, 0.8353, 0.8706, 0.8627,
#            0.9608, 0.4667, 0.6549, 0.2196],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0157, 0.0000, 0.0000, 0.2157, 0.9255, 0.8941, 0.9020,
#            0.8941, 0.9412, 0.9098, 0.8353, 0.8549, 0.8745, 0.9176, 0.8510,
#            0.8510, 0.8196, 0.3608, 0.0000],
#           [0.0000, 0.0000, 0.0039, 0.0157, 0.0235, 0.0275, 0.0078, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.9294, 0.8863, 0.8510, 0.8745,
#            0.8706, 0.8588, 0.8706, 0.8667, 0.8471, 0.8745, 0.8980, 0.8431,
#            0.8549, 1.0000, 0.3020, 0.0000],
#           [0.0000, 0.0118, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.2431, 0.5686, 0.8000, 0.8941, 0.8118, 0.8353, 0.8667,
#            0.8549, 0.8157, 0.8275, 0.8549, 0.8784, 0.8745, 0.8588, 0.8431,
#            0.8784, 0.9569, 0.6235, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0706, 0.1725, 0.3216, 0.4196,
#            0.7412, 0.8941, 0.8627, 0.8706, 0.8510, 0.8863, 0.7843, 0.8039,
#            0.8275, 0.9020, 0.8784, 0.9176, 0.6902, 0.7373, 0.9804, 0.9725,
#            0.9137, 0.9333, 0.8431, 0.0000],
#           [0.0000, 0.2235, 0.7333, 0.8157, 0.8784, 0.8667, 0.8784, 0.8157,
#            0.8000, 0.8392, 0.8157, 0.8196, 0.7843, 0.6235, 0.9608, 0.7569,
#            0.8078, 0.8745, 1.0000, 1.0000, 0.8667, 0.9176, 0.8667, 0.8275,
#            0.8627, 0.9098, 0.9647, 0.0000],
#           [0.0118, 0.7922, 0.8941, 0.8784, 0.8667, 0.8275, 0.8275, 0.8392,
#            0.8039, 0.8039, 0.8039, 0.8627, 0.9412, 0.3137, 0.5882, 1.0000,
#            0.8980, 0.8667, 0.7373, 0.6039, 0.7490, 0.8235, 0.8000, 0.8196,
#            0.8706, 0.8941, 0.8824, 0.0000],
#           [0.3843, 0.9137, 0.7765, 0.8235, 0.8706, 0.8980, 0.8980, 0.9176,
#            0.9765, 0.8627, 0.7608, 0.8431, 0.8510, 0.9451, 0.2549, 0.2863,
#            0.4157, 0.4588, 0.6588, 0.8588, 0.8667, 0.8431, 0.8510, 0.8745,
#            0.8745, 0.8784, 0.8980, 0.1137],
#           [0.2941, 0.8000, 0.8314, 0.8000, 0.7569, 0.8039, 0.8275, 0.8824,
#            0.8471, 0.7255, 0.7725, 0.8078, 0.7765, 0.8353, 0.9412, 0.7647,
#            0.8902, 0.9608, 0.9373, 0.8745, 0.8549, 0.8314, 0.8196, 0.8706,
#            0.8627, 0.8667, 0.9020, 0.2627],
#           [0.1882, 0.7961, 0.7176, 0.7608, 0.8353, 0.7725, 0.7255, 0.7451,
#            0.7608, 0.7529, 0.7922, 0.8392, 0.8588, 0.8667, 0.8627, 0.9255,
#            0.8824, 0.8471, 0.7804, 0.8078, 0.7294, 0.7098, 0.6941, 0.6745,
#            0.7098, 0.8039, 0.8078, 0.4510],
#           [0.0000, 0.4784, 0.8588, 0.7569, 0.7020, 0.6706, 0.7176, 0.7686,
#            0.8000, 0.8235, 0.8353, 0.8118, 0.8275, 0.8235, 0.7843, 0.7686,
#            0.7608, 0.7490, 0.7647, 0.7490, 0.7765, 0.7529, 0.6902, 0.6118,
#            0.6549, 0.6941, 0.8235, 0.3608],
#           [0.0000, 0.0000, 0.2902, 0.7412, 0.8314, 0.7490, 0.6863, 0.6745,
#            0.6863, 0.7098, 0.7255, 0.7373, 0.7412, 0.7373, 0.7569, 0.7765,
#            0.8000, 0.8196, 0.8235, 0.8235, 0.8275, 0.7373, 0.7373, 0.7608,
#            0.7529, 0.8471, 0.6667, 0.0000],
#           [0.0078, 0.0000, 0.0000, 0.0000, 0.2588, 0.7843, 0.8706, 0.9294,
#            0.9373, 0.9490, 0.9647, 0.9529, 0.9569, 0.8667, 0.8627, 0.7569,
#            0.7490, 0.7020, 0.7137, 0.7137, 0.7098, 0.6902, 0.6510, 0.6588,
#            0.3882, 0.2275, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.1569,
#            0.2392, 0.1725, 0.2824, 0.1608, 0.1373, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000]]]),
#  9)

# %% [markdown]
# The shape of the image tensor is `[1, 28, 28]` or more specifically:
#
# ```
# [color_channels=1, height=28, width=28]
# ```
#
# Having `color_channels=1` means the image is grayscale.
#
# ![example input and output shapes of the fashionMNIST problem](https://raw.githubusercontent.com/mrdbourke/pytorch-deep-learning/main/images/03-computer-vision-input-and-output-shapes.png)
# *Various problems will have various input and output shapes. But the premise reamins: encode data into numbers, build a model to find patterns in those numbers, convert those patterns into something meaningful.*
#
# If `color_channels=3`, the image comes in pixel values for red, green and blue (this is also known a the [RGB color model](https://en.wikipedia.org/wiki/RGB_color_model)).
#
# The order of our current tensor is often referred to as `CHW` (Color Channels, Height, Width).
#
# There's debate on whether images should be represented as `CHW` (color channels first) or `HWC` (color channels last).
#
# > **Note:** You'll also see `NCHW` and `NHWC` formats where `N` stands for *number of images*. For example if you have a `batch_size=32`, your tensor shape may be `[32, 1, 28, 28]`. We'll cover batch sizes later.
#
# PyTorch generally accepts `NCHW` (channels first) as the default for many operators.

# %%
# See classes
class_names = train_data.classes
class_names
# Out:
# ['T-shirt/top',
#  'Trouser',
#  'Pullover',
#  'Dress',
#  'Coat',
#  'Sandal',
#  'Shirt',
#  'Sneaker',
#  'Bag',
#  'Ankle boot']

# %%
# Ex 1 Print the len of the train and test datasets

# %%
print(len(train_data))
print(len(test_data))
# Out:
# 60000
# 10000

# %%
import matplotlib.pyplot as plt
image, label = train_data[0]
print(f"Image shape: {image.shape}")
plt.imshow(image.squeeze()) # image shape is [1, 28, 28] (colour channels, height, width)
plt.title(label);
# Out:
# Image shape: torch.Size([1, 28, 28])

# %%
# Now let's look at some random images
# Ex 3 Access some random data from train_data

import random

random_idx = random.randint(0, len(train_data))
img, label = train_data[random_idx]
plt.imshow(img.squeeze())
plt.title(class_names[label])
# Out:
# Text(0.5, 1.0, 'Bag')

# %%
# Plot more images
torch.manual_seed(42)
fig = plt.figure(figsize=(9, 9))
rows, cols = 4, 4
for i in range(1, rows * cols + 1):
    random_idx = torch.randint(0, len(train_data), size=[1]).item()
    # Ex 3 here
    fig.add_subplot(rows, cols, i)
    plt.imshow(img.squeeze(), cmap="gray")
    plt.title(class_names[label])
    plt.axis(False);

# %% [markdown]
# ## 2. Prepare DataLoader
#
# Now we've got a dataset ready to go.
#
# The next step is to prepare it with a [`torch.utils.data.DataLoader`](https://pytorch.org/docs/stable/data.html#torch.utils.data.Dataset) or `DataLoader` for short.
#
# The `DataLoader` does what you think it might do.
#
# It helps load data into a model.
#
# For training and for inference.
#
# It turns a large `Dataset` into a Python iterable of smaller chunks.
#
# These smaller chunks are called **batches** or **mini-batches** and can be set by the `batch_size` parameter.
#
# Why do this?
#
# Because it's more computationally efficient.
#
# In an ideal world you could do the forward pass and backward pass across all of your data at once.
#
# But once you start using really large datasets, unless you've got infinite computing power, it's easier to break them up into batches.
#
# It also gives your model more opportunities to improve.
#
# With **mini-batches** (small portions of the data), gradient descent is performed more often per epoch (once per mini-batch rather than once per epoch).
#
# What's a good batch size?
#
# [32 is a good place to start](https://twitter.com/ylecun/status/989610208497360896?s=20&t=N96J_jotN--PYuJk2WcjMw) for a fair amount of problems.
#
# But since this is a value you can set (a **hyperparameter**) you can try all different kinds of values, though generally powers of 2 are used most often (e.g. 32, 64, 128, 256, 512).

# %%
from torch.utils.data import DataLoader

# Setup the batch size hyperparameter
BATCH_SIZE = 32

# Turn datasets into iterables (batches)
train_dataloader = DataLoader(train_data, # dataset to turn into iterable
    batch_size=BATCH_SIZE, # how many samples per batch? 
    shuffle=True # shuffle data every epoch?
)

test_dataloader = DataLoader(test_data,
    batch_size=BATCH_SIZE,
    shuffle=False # don't necessarily have to shuffle the testing data
)

# Let's check out what we've created
print(f"Dataloaders: {train_dataloader, test_dataloader}") 
print(f"Length of train dataloader: {len(train_dataloader)} batches of {BATCH_SIZE}")
print(f"Length of test dataloader: {len(test_dataloader)} batches of {BATCH_SIZE}")
# Out:
# Dataloaders: (<torch.utils.data.dataloader.DataLoader object at 0x00000168CEC9C7C0>, <torch.utils.data.dataloader.DataLoader object at 0x00000168CECA7E80>)
# Length of train dataloader: 1875 batches of 32
# Length of test dataloader: 313 batches of 32

# %% [markdown]
# # First Dumb Model

# %% [markdown]
# Data loaded and prepared!
#
# Time to build a **baseline model** by subclassing `nn.Module`.
#
# A **baseline model** is one of the simplest models you can imagine.
#
# You use the baseline as a starting point and try to improve upon it with subsequent, more complicated models.

# %%
# Check out what's inside the training dataloader
# This is how we get some random samples
train_features_batch, train_labels_batch = next(iter(train_dataloader))
train_features_batch.shape, train_labels_batch.shape
# Out:
# (torch.Size([32, 1, 28, 28]), torch.Size([32]))

# %%
# Ex 4 Use Flatten + 2x Linear layer for the base model

# %%
from torch import nn
class FashionMNISTModelV0(nn.Module):
    def __init__(self, input_shape: int, hidden_units: int, output_shape: int):
        super().__init__()
        self.layer_stack = nn.Sequential(
            nn.Flatten(),
            nn.Linear(input_shape, hidden_units),
            nn.Linear(hidden_units, output_shape)
        )
        
    def forward(self, x):
        return self.layer_stack(x)

# %%
torch.manual_seed(42)

# Need to setup model with input parameters
model_0 = FashionMNISTModelV0(input_shape=784, # one for every pixel (28x28)
    hidden_units=10, # how many units in the hiden layer
    output_shape=len(class_names) # one for every class
)

# %%
def accuracy_fn(y_true, y_pred):
    """Calculates accuracy between truth labels and predictions.

    Args:
        y_true (torch.Tensor): Truth labels for predictions.
        y_pred (torch.Tensor): Predictions to be compared to predictions.

    Returns:
        [torch.float]: Accuracy value between y_true and y_pred, e.g. 78.45
    """
    correct = torch.eq(y_true, y_pred).sum().item()
    acc = (correct / len(y_pred)) * 100
    return acc

# %%
# Ex 5 Define the loss as Cross Entropy loss and the sgd optimizer

# %%
from timeit import default_timer as timer 
def print_train_time(start: float, end: float, device: torch.device = None):
    """Prints difference between start and end time.

    Args:
        start (float): Start time of computation (preferred in timeit format). 
        end (float): End time of computation.
        device ([type], optional): Device that compute is running on. Defaults to None.

    Returns:
        float: time between start and end in seconds (higher is longer).
    """
    total_time = end - start
    print(f"Train time on {device}: {total_time:.3f} seconds")
    return total_time

# %%
# Ex 6 Create a loss_values_arr and plot it after the training loop

# %%
# Ex 7 Finish the training loop instructions

# %%
# Import tqdm for progress bar
from tqdm.auto import tqdm

def train_model(model, cnn=False):
    # Set the seed and start the timer
    torch.manual_seed(42)
    train_time_start_on_cpu = timer()
    # Set the number of epochs (we'll keep this small for faster training times)
    epochs = 3
    loss_values_arr = []
    # Set the loss function and optimizer
    loss_fn = nn.CrossEntropyLoss()
    optimizer = torch.optim.SGD(model.parameters(), lr=0.1)
    # Create training and testing loop
    for epoch in tqdm(range(epochs)):
        print(f"Epoch: {epoch}\n-------")
        ### Training
        train_loss = 0
        # Add a loop to loop through training batches
        for batch, (X, y) in enumerate(train_dataloader):
            model.train()
            # 1. Forward pass
            y_pred = model(X)
            # 2. Calculate loss (per batch)
            loss = loss_fn(y_pred, y)
            loss_values_arr.append(loss)
            # 3. Optimizer zero grad
            optimizer.zero_grad()
            # 4. Loss backward
            loss.backward()
            # 5. Optimizer step
            optimizer.step()
            # Print out how many samples have been seen
            if batch % 400 == 0:
                print(f"Looked at {batch * len(X)}/{len(train_dataloader.dataset)} samples")

        # Divide total training loss by length of training dataloader (per batch)
        ### Testing
        # Setup variables for accumulatively adding up loss and accuracy
        test_loss, test_acc = 0, 0
        model.eval()
        with torch.inference_mode():
            for X, y in test_dataloader:
                # 1. Forward pass
                test_pred = model(X)

                # 2. Calculate loss (accumatively)
                test_loss += loss_fn(test_pred, y) # accumulatively add up the loss per epoch

                # 3. Calculate accuracy (preds need to be same as y_true)
                test_acc += accuracy_fn(y_true=y, y_pred=test_pred.argmax(dim=1))

            # Calculations on test metrics need to happen inside torch.inference_mode()
            # Divide total test loss by length of test dataloader (per batch)
            test_loss /= len(test_dataloader)

            # Divide total accuracy by length of test dataloader (per batch)
            test_acc /= len(test_dataloader)

        ## Print out what's happening
        print(f"\nTrain loss: {train_loss:.5f} | Test loss: {test_loss:.5f}, Test acc: {test_acc:.2f}%\n")



    # Calculate training time
    train_time_end_on_cpu = timer()
    total_train_time_model_0 = print_train_time(start=train_time_start_on_cpu,
                                               end=train_time_end_on_cpu)
    return model, [x.detach().numpy() for x in  loss_values_arr]

# %%
def plot_loss_values(loss_values_arr):
    plt.plot(loss_values_arr, label="Loss")
    plt.title("Loss values over time")
    plt.xlabel("Batch number")
    plt.ylabel("Loss value")
    plt.legend()
    plt.show()

# %%
_, arr = train_model(model_0)
plot_loss_values(arr)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch: 0
# -------
# Looked at 0/60000 samples
# Looked at 12800/60000 samples
# Looked at 25600/60000 samples
# Looked at 38400/60000 samples
# Looked at 51200/60000 samples
#
# Train loss: 0.00000 | Test loss: 0.45465, Test acc: 84.05%
#
# Epoch: 1
# -------
# Looked at 0/60000 samples
# Looked at 12800/60000 samples
# Looked at 25600/60000 samples
# Looked at 38400/60000 samples
# Looked at 51200/60000 samples
#
# Train loss: 0.00000 | Test loss: 0.45686, Test acc: 84.22%
#
# Epoch: 2
# -------
# Looked at 0/60000 samples
# Looked at 12800/60000 samples
# Looked at 25600/60000 samples
# Looked at 38400/60000 samples
# Looked at 51200/60000 samples
#
# Train loss: 0.00000 | Test loss: 0.46174, Test acc: 84.21%
#
# Train time on None: 33.644 seconds

# %%
# The model is looking good

# %% [markdown]
# # Evaluate baseline model

# %%
torch.manual_seed(42)
def eval_model(model: torch.nn.Module, 
               data_loader: torch.utils.data.DataLoader, 
               loss_fn: torch.nn.Module, 
               accuracy_fn):
    """Returns a dictionary containing the results of model predicting on data_loader.

    Args:
        model (torch.nn.Module): A PyTorch model capable of making predictions on data_loader.
        data_loader (torch.utils.data.DataLoader): The target dataset to predict on.
        loss_fn (torch.nn.Module): The loss function of model.
        accuracy_fn: An accuracy function to compare the models predictions to the truth labels.

    Returns:
        (dict): Results of model making predictions on data_loader.
    """
    loss, acc = 0, 0
    model.eval()
    with torch.inference_mode():
        for X, y in data_loader:
            # Make predictions with the model
            y_pred = model(X)
            
            # Accumulate the loss and accuracy values per batch
            loss += loss_fn(y_pred, y)
            acc += accuracy_fn(y_true=y, 
                                y_pred=y_pred.argmax(dim=1)) # For accuracy, need the prediction labels (logits -> pred_prob -> pred_labels)
        
        # Scale loss and acc to find the average loss/acc per batch
        loss /= len(data_loader)
        acc /= len(data_loader)
        
    return {"model_name": model.__class__.__name__, # only works when model was created with a class
            "model_loss": loss.item(),
            "model_acc": acc}

# Calculate model 0 results on test dataset
model_0_results = eval_model(model=model_0, data_loader=test_dataloader,
    loss_fn=loss_fn, accuracy_fn=accuracy_fn
)
model_0_results
# Out:
# {'model_name': 'FashionMNISTModelV0',
#  'model_loss': 0.4617440700531006,
#  'model_acc': 84.20527156549521}

# %% [markdown]
# # Setup device agnostic code
# import torch
# device = "cuda" if torch.cuda.is_available() else "cpu"
# device# Task 9 : Recreate the model by adding non linearities
# #### The model needs again to flatten the image to a 1 D array and then add in between the linear layers ReLU
# #### At the end you will have Flatten + Linear + ReLU + Linear + ReLU
# #### We also try to speed up thing

# %%
# Setup device agnostic code
import torch
device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cpu'

# %%
from torch import nn
class FashionMNISTModelV1(nn.Module):
    def __init__(self, input_shape: int, hidden_units: int, output_shape: int):
        super().__init__()
        self.layer_stack = nn.Sequential(
            nn.Flatten(),
            nn.Linear(input_shape, hidden_units),
            nn.ReLU(),
            nn.Linear(hidden_units, output_shape),
        )
        
    def forward(self, x):
        return self.layer_stack(x)

# %%
torch.manual_seed(42)
model_1 = FashionMNISTModelV1(input_shape=784, # number of input features
    hidden_units=10,
    output_shape=len(class_names) # number of output classes desired
).to(device) # send model to GPU if it's available
next(model_1.parameters()).device # check model device
# Out:
# device(type='cpu')

# %%
# Task 10 Create the same loss + Optimizer as for V0

## Make sure to use after the for loop if you are using a gpu      
# Send data to GPU
# X, y = X.to(device), y.to(device)

# %%
# Task 11 Train And Test it as before
train_model(model_1)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch: 0
# -------
# Looked at 0/60000 samples
# Looked at 12800/60000 samples
# Looked at 25600/60000 samples
# Looked at 38400/60000 samples
# Looked at 51200/60000 samples
#
# Train loss: 0.00000 | Test loss: 0.53855, Test acc: 80.76%
#
# Epoch: 1
# -------
# Looked at 0/60000 samples
# Looked at 12800/60000 samples
# Looked at 25600/60000 samples
# Looked at 38400/60000 samples
# Looked at 51200/60000 samples
#
# Train loss: 0.00000 | Test loss: 0.49390, Test acc: 82.46%
#
# Epoch: 2
# -------
# Looked at 0/60000 samples
# Looked at 12800/60000 samples
# Looked at 25600/60000 samples
# Looked at 38400/60000 samples
# Looked at 51200/60000 samples
#
# Train loss: 0.00000 | Test loss: 0.45746, Test acc: 83.99%
#
# Train time on None: 33.052 seconds
# (FashionMNISTModelV1(
#    (layer_stack): Sequential(
#      (0): Flatten(start_dim=1, end_dim=-1)
#      (1): Linear(in_features=784, out_features=10, bias=True)
#      (2): ReLU()
#      (3): Linear(in_features=10, out_features=10, bias=True)
#    )
#  ),
#  [array(2.320255, dtype=float32),
#   array(2.288983, dtype=float32),
#   array(2.2644565, dtype=float32),
#   array(2.3021436, dtype=float32),
#   array(2.2935646, dtype=float32),
#   array(2.3324716, dtype=float32),
#   array(2.2363298, dtype=float32),
#   array(2.2311032, dtype=float32),
#   array(2.2758079, dtype=float32),
#   array(2.2274106, dtype=float32),
#   array(2.184415, dtype=float32),
#   array(2.1775045, dtype=float32),
#   array(2.1890075, dtype=float32),
#   array(2.1826074, dtype=float32),
#   array(2.0955255, dtype=float32),
#   array(2.0926049, dtype=float32),
#   array(2.1100044, dtype=float32),
#   array(2.0997345, dtype=float32),
#   array(1.961344, dtype=float32),
#   array(2.1482942, dtype=float32),
#   array(2.04504, dtype=float32),
#   array(1.9561292, dtype=float32),
#   array(2.049501, dtype=float32),
#   array(1.8777838, dtype=float32),
#   array(1.9133309, dtype=float32),
#   array(1.9907953, dtype=float32),
#   array(1.9040208, dtype=float32),
#   array(1.8877271, dtype=float32),
#   array(1.836165, dtype=float32),
#   array(1.7807536, dtype=float32),
#   array(1.9202774, dtype=float32),
#   array(1.8057435, dtype=float32),
#   array(1.8408403, dtype=float32),
#   array(1.7023166, dtype=float32),
#   array(1.7209246, dtype=float32),
#   array(1.6769346, dtype=float32),
#   array(1.9224287, dtype=float32),
#   array(1.5045689, dtype=float32),
#   array(1.6403775, dtype=float32),
#   array(1.5824413, dtype=float32),
#   array(1.6894964, dtype=float32),
#   array(1.6360734, dtype=float32),
#   array(1.4873604, dtype=float32),
#   array(1.712216, dtype=float32),
#   array(1.4915112, dtype=float32),
#   array(1.5308086, dtype=float32),
#   array(1.4954094, dtype=float32),
#   array(1.1926196, dtype=float32),
#   array(1.5176903, dtype=float32),
#   array(1.2868297, dtype=float32),
#   array(1.3935932, dtype=float32),
#   array(1.3862977, dtype=float32),
#   array(1.2518165, dtype=float32),
#   array(1.2945391, dtype=float32),
#   array(1.6557096, dtype=float32),
#   array(1.3207484, dtype=float32),
#   array(1.1936227, dtype=float32),
#   array(1.0748596, dtype=float32),
#   array(1.1305262, dtype=float32),
#   array(1.3822039, dtype=float32),
#   array(1.222651, dtype=float32),
#   array(1.168782, dtype=float32),
#   array(1.091493, dtype=float32),
#   array(1.0480412, dtype=float32),
#   array(1.3385779, dtype=float32),
#   array(1.1872268, dtype=float32),
#   array(1.2104446, dtype=float32),
#   array(1.0097569, dtype=float32),
#   array(1.0483489, dtype=float32),
#   array(1.2735823, dtype=float32),
#   array(0.9745003, dtype=float32),
#   array(1.1389637, dtype=float32),
#   array(0.8501106, dtype=float32),
#   array(1.0525875, dtype=float32),
#   array(1.0926827, dtype=float32),
#   array(1.3200305, dtype=float32),
#   array(1.2307031, dtype=float32),
#   array(0.9402008, dtype=float32),
#   array(1.3523626, dtype=float32),
#   array(1.2912347, dtype=float32),
#   array(0.9518189, dtype=float32),
#   array(1.1553708, dtype=float32),
#   array(1.1204793, dtype=float32),
#   array(1.2650341, dtype=float32),
#   array(0.9852735, dtype=float32),
#   array(0.81137615, dtype=float32),
#   array(0.8943887, dtype=float32),
#   array(1.0511359, dtype=float32),
#   array(0.86609375, dtype=float32),
#   array(0.9333619, dtype=float32),
#   array(1.2450411, dtype=float32),
#   array(0.90237635, dtype=float32),
#   array(0.91177464, dtype=float32),
#   array(1.2007707, dtype=float32),
#   array(0.86628675, dtype=float32),
#   array(1.0244501, dtype=float32),
#   array(0.7177588, dtype=float32),
#   array(1.0451664, dtype=float32),
#   array(0.80004394, dtype=float32),
#   array(0.8346808, dtype=float32),
#   array(0.7873013, dtype=float32),
#   array(1.2788515, dtype=float32),
#   array(0.96849376, dtype=float32),
#   array(0.9332098, dtype=float32),
#   array(0.96256447, dtype=float32),
#   array(0.8128452, dtype=float32),
#   array(0.999289, dtype=float32),
#   array(0.88920957, dtype=float32),
#   array(1.0732888, dtype=float32),
#   array(0.9374369, dtype=float32),
#   array(0.8130747, dtype=float32),
#   array(0.9537957, dtype=float32),
#   array(1.0158685, dtype=float32),
#   array(1.2562411, dtype=float32),
#   array(1.0387665, dtype=float32),
#   array(0.82993287, dtype=float32),
#   array(0.927376, dtype=float32),
#   array(0.8164633, dtype=float32),
#   array(1.0603806, dtype=float32),
#   array(0.99323356, dtype=float32),
#   array(1.0354707, dtype=float32),
#   array(1.0751739, dtype=float32),
#   array(1.4044474, dtype=float32),
#   array(0.8644087, dtype=float32),
#   array(0.9059426, dtype=float32),
#   array(0.8975007, dtype=float32),
#   array(0.89546305, dtype=float32),
#   array(1.061506, dtype=float32),
#   array(0.87179995, dtype=float32),
#   array(0.72123283, dtype=float32),
#   array(0.84818894, dtype=float32),
#   array(0.7662745, dtype=float32),
#   array(0.997037, dtype=float32),
#   array(0.6556621, dtype=float32),
#   array(0.8723415, dtype=float32),
#   array(0.80350846, dtype=float32),
#   array(0.7964785, dtype=float32),
#   array(0.8229724, dtype=float32),
#   array(0.9677763, dtype=float32),
#   array(0.7466803, dtype=float32),
#   array(0.9191643, dtype=float32),
#   array(0.612547, dtype=float32),
#   array(1.1311438, dtype=float32),
#   array(0.7233817, dtype=float32),
#   array(0.74250406, dtype=float32),
#   array(0.8628877, dtype=float32),
#   array(0.866365, dtype=float32),
#   array(0.6645452, dtype=float32),
#   array(1.0878593, dtype=float32),
#   array(0.6923079, dtype=float32),
#   array(0.7105112, dtype=float32),
#   array(0.9813635, dtype=float32),
#   array(0.74732435, dtype=float32),
#   array(0.7314144, dtype=float32),
#   array(0.84616905, dtype=float32),
#   array(1.032049, dtype=float32),
#   array(0.5581104, dtype=float32),
#   array(0.8228189, dtype=float32),
#   array(1.0602137, dtype=float32),
#   array(0.8804715, dtype=float32),
#   array(0.7849946, dtype=float32),
#   array(0.6051646, dtype=float32),
#   array(0.7568883, dtype=float32),
#   array(0.9809003, dtype=float32),
#   array(0.87939346, dtype=float32),
#   array(1.0453664, dtype=float32),
#   array(0.80273545, dtype=float32),
#   array(0.6999084, dtype=float32),
#   array(0.8481653, dtype=float32),
#   array(0.76631755, dtype=float32),
#   array(0.81374514, dtype=float32),
#   array(0.7794226, dtype=float32),
#   array(0.7679859, dtype=float32),
#   array(0.8255008, dtype=float32),
#   array(0.9192346, dtype=float32),
#   array(0.8169385, dtype=float32),
#   array(0.63149476, dtype=float32),
#   array(0.71991396, dtype=float32),
#   array(0.7012429, dtype=float32),
#   array(0.689644, dtype=float32),
#   array(0.5909225, dtype=float32),
#   array(0.7443103, dtype=float32),
#   array(1.0138845, dtype=float32),
#   array(0.8132139, dtype=float32),
#   array(0.78949106, dtype=float32),
#   array(0.8100506, dtype=float32),
#   array(0.7918781, dtype=float32),
#   array(0.6545934, dtype=float32),
#   array(0.66425186, dtype=float32),
#   array(0.7210681, dtype=float32),
#   array(0.6185642, dtype=float32),
#   array(0.8639458, dtype=float32),
#   array(0.66191536, dtype=float32),
#   array(0.73353505, dtype=float32),
#   array(0.757132, dtype=float32),
#   array(0.68476003, dtype=float32),
#   array(0.6911851, dtype=float32),
#   array(0.6721151, dtype=float32),
#   array(0.8871691, dtype=float32),
#   array(0.6743631, dtype=float32),
#   array(0.58075833, dtype=float32),
#   array(0.8029399, dtype=float32),
#   array(0.7240771, dtype=float32),
#   array(0.824409, dtype=float32),
#   array(0.59948295, dtype=float32),
#   array(0.8010793, dtype=float32),
#   array(0.5887373, dtype=float32),
#   array(0.75484943, dtype=float32),
#   array(1.0506288, dtype=float32),
#   array(0.7307999, dtype=float32),
#   array(0.72205764, dtype=float32),
#   array(0.7123284, dtype=float32),
#   array(0.69567597, dtype=float32),
#   array(0.59142834, dtype=float32),
#   array(0.6138327, dtype=float32),
#   array(0.7995219, dtype=float32),
#   array(0.81932175, dtype=float32),
#   array(0.7590306, dtype=float32),
#   array(0.9337804, dtype=float32),
#   array(0.684205, dtype=float32),
#   array(0.97537106, dtype=float32),
#   array(0.5854834, dtype=float32),
#   array(0.7675285, dtype=float32),
#   array(0.5671435, dtype=float32),
#   array(0.611072, dtype=float32),
#   array(0.8999095, dtype=float32),
#   array(0.84736717, dtype=float32),
#   array(0.72437835, dtype=float32),
#   array(0.9289649, dtype=float32),
#   array(0.86327785, dtype=float32),
#   array(0.6126191, dtype=float32),
#   array(1.0384114, dtype=float32),
#   array(0.5163941, dtype=float32),
#   array(0.6215042, dtype=float32),
#   array(0.6951205, dtype=float32),
#   array(1.0524138, dtype=float32),
#   array(0.97539234, dtype=float32),
#   array(0.8413343, dtype=float32),
#   array(0.5883106, dtype=float32),
#   array(0.48345643, dtype=float32),
#   array(0.6502625, dtype=float32),
#   array(1.0486072, dtype=float32),
#   array(0.6756722, dtype=float32),
#   array(0.78171813, dtype=float32),
#   array(0.8031319, dtype=float32),
#   array(0.45193797, dtype=float32),
#   array(0.62535834, dtype=float32),
#   array(0.87909317, dtype=float32),
#   array(1.0453688, dtype=float32),
#   array(0.7362582, dtype=float32),
#   array(0.7565248, dtype=float32),
#   array(0.5753904, dtype=float32),
#   array(0.6336875, dtype=float32),
#   array(0.7839125, dtype=float32),
#   array(0.6435307, dtype=float32),
#   array(0.7596482, dtype=float32),
#   array(0.62372327, dtype=float32),
#   array(0.55462897, dtype=float32),
#   array(0.6388022, dtype=float32),
#   array(0.80652755, dtype=float32),
#   array(0.75623745, dtype=float32),
#   array(0.6987738, dtype=float32),
#   array(0.5560403, dtype=float32),
#   array(1.0666093, dtype=float32),
#   array(0.67080545, dtype=float32),
#   array(0.7352121, dtype=float32),
#   array(0.53144646, dtype=float32),
#   array(0.5339187, dtype=float32),
#   array(0.6422813, dtype=float32),
#   array(0.58350545, dtype=float32),
#   array(0.7306321, dtype=float32),
#   array(0.8621786, dtype=float32),
#   array(0.6746743, dtype=float32),
#   array(1.1881518, dtype=float32),
#   array(0.6708879, dtype=float32),
#   array(0.5026401, dtype=float32),
#   array(0.6844184, dtype=float32),
#   array(0.7484543, dtype=float32),
#   array(0.7569024, dtype=float32),
#   array(0.77077603, dtype=float32),
#   array(0.58328635, dtype=float32),
#   array(0.7550873, dtype=float32),
#   array(0.58668584, dtype=float32),
#   array(0.7563724, dtype=float32),
#   array(0.78569394, dtype=float32),
#   array(0.6035406, dtype=float32),
#   array(0.8934197, dtype=float32),
#   array(0.6632484, dtype=float32),
#   array(0.50318485, dtype=float32),
#   array(0.56121665, dtype=float32),
#   array(0.73727894, dtype=float32),
#   array(0.5227219, dtype=float32),
#   array(0.8110706, dtype=float32),
#   array(1.2067266, dtype=float32),
#   array(0.54655075, dtype=float32),
#   array(1.0223235, dtype=float32),
#   array(0.8376797, dtype=float32),
#   array(0.78589237, dtype=float32),
#   array(0.7894833, dtype=float32),
#   array(0.8726342, dtype=float32),
#   array(0.72041386, dtype=float32),
#   array(0.980143, dtype=float32),
#   array(0.82516754, dtype=float32),
#   array(0.7286507, dtype=float32),
#   array(0.46797764, dtype=float32),
#   array(0.60562253, dtype=float32),
#   array(0.7911565, dtype=float32),
#   array(0.67268497, dtype=float32),
#   array(0.5415366, dtype=float32),
#   array(0.54085875, dtype=float32),
#   array(0.736636, dtype=float32),
#   array(0.89845514, dtype=float32),
#   array(0.60303736, dtype=float32),
#   array(0.5692107, dtype=float32),
#   array(0.6510703, dtype=float32),
#   array(0.50299305, dtype=float32),
#   array(0.9209848, dtype=float32),
#   array(1.089682, dtype=float32),
#   array(1.0298519, dtype=float32),
#   array(0.54544026, dtype=float32),
#   array(0.714132, dtype=float32),
#   array(0.67452437, dtype=float32),
#   array(0.65331376, dtype=float32),
#   array(0.5817946, dtype=float32),
#   array(0.68178767, dtype=float32),
#   array(0.7849236, dtype=float32),
#   array(0.6519923, dtype=float32),
#   array(0.52603024, dtype=float32),
#   array(0.6177303, dtype=float32),
#   array(0.7281887, dtype=float32),
#   array(0.95629805, dtype=float32),
#   array(0.8146516, dtype=float32),
#   array(0.8095136, dtype=float32),
#   array(0.6858876, dtype=float32),
#   array(0.79629815, dtype=float32),
#   array(0.6244683, dtype=float32),
#   array(0.89460456, dtype=float32),
#   array(0.5405755, dtype=float32),
#   array(0.7228401, dtype=float32),
#   array(0.47004732, dtype=float32),
#   array(0.6214061, dtype=float32),
#   array(0.6091752, dtype=float32),
#   array(0.7717019, dtype=float32),
#   array(1.1661524, dtype=float32),
#   array(0.6645834, dtype=float32),
#   array(1.0102518, dtype=float32),
#   array(0.3693709, dtype=float32),
#   array(0.9326901, dtype=float32),
#   array(0.8933859, dtype=float32),
#   array(0.8593658, dtype=float32),
#   array(0.60122573, dtype=float32),
#   array(0.4004924, dtype=float32),
#   array(0.57492787, dtype=float32),
#   array(0.54546183, dtype=float32),
#   array(0.5669168, dtype=float32),
#   array(0.55025005, dtype=float32),
#   array(0.45029965, dtype=float32),
#   array(0.6328774, dtype=float32),
#   array(0.6759914, dtype=float32),
#   array(0.61340654, dtype=float32),
#   array(0.71638805, dtype=float32),
#   array(0.72070956, dtype=float32),
#   array(0.72715837, dtype=float32),
#   array(0.7596391, dtype=float32),
#   array(0.74105376, dtype=float32),
#   array(0.7860855, dtype=float32),
#   array(0.7034221, dtype=float32),
#   array(0.55180377, dtype=float32),
#   array(0.7477439, dtype=float32),
#   array(0.8154452, dtype=float32),
#   array(0.66739523, dtype=float32),
#   array(0.82355875, dtype=float32),
#   array(0.83928573, dtype=float32),
#   array(0.5748267, dtype=float32),
#   array(0.6739207, dtype=float32),
#   array(0.7642179, dtype=float32),
#   array(0.71869695, dtype=float32),
#   array(0.78308886, dtype=float32),
#   array(0.8296165, dtype=float32),
#   array(0.7572377, dtype=float32),
#   array(0.6323363, dtype=float32),
#   array(0.44798774, dtype=float32),
#   array(0.56443423, dtype=float32),
#   array(0.51309943, dtype=float32),
#   array(0.6448925, dtype=float32),
#   array(0.6362019, dtype=float32),
#   array(0.40664405, dtype=float32),
#   array(0.51354885, dtype=float32),
#   array(0.33333394, dtype=float32),
#   array(0.7319137, dtype=float32),
#   array(0.7115034, dtype=float32),
#   array(0.53591245, dtype=float32),
#   array(0.83992624, dtype=float32),
#   array(0.4644183, dtype=float32),
#   array(0.7813224, dtype=float32),
#   array(0.56606114, dtype=float32),
#   array(0.743921, dtype=float32),
#   array(0.38873997, dtype=float32),
#   array(0.61640084, dtype=float32),
#   array(0.59378177, dtype=float32),
#   array(0.73845387, dtype=float32),
#   array(0.65740854, dtype=float32),
#   array(0.6518431, dtype=float32),
#   array(0.7484994, dtype=float32),
#   array(0.74456173, dtype=float32),
#   array(0.5447662, dtype=float32),
#   array(0.6703038, dtype=float32),
#   array(0.4780296, dtype=float32),
#   array(0.6895131, dtype=float32),
#   array(0.7528175, dtype=float32),
#   array(0.88949835, dtype=float32),
#   array(0.6030586, dtype=float32),
#   array(0.5762224, dtype=float32),
#   array(0.59299463, dtype=float32),
#   array(0.8132158, dtype=float32),
#   array(0.37790132, dtype=float32),
#   array(0.6157734, dtype=float32),
#   array(0.7307893, dtype=float32),
#   array(0.4690349, dtype=float32),
#   array(0.7797818, dtype=float32),
#   array(0.7855958, dtype=float32),
#   array(0.69679856, dtype=float32),
#   array(0.5454392, dtype=float32),
#   array(0.7345415, dtype=float32),
#   array(0.5809613, dtype=float32),
#   array(0.64469516, dtype=float32),
#   array(0.5390329, dtype=float32),
#   array(0.8826455, dtype=float32),
#   array(0.47985354, dtype=float32),
#   array(0.5761909, dtype=float32),
#   array(0.572746, dtype=float32),
#   array(0.9165808, dtype=float32),
#   array(0.4736035, dtype=float32),
#   array(0.86397153, dtype=float32),
#   array(0.41650593, dtype=float32),
#   array(0.6043002, dtype=float32),
#   array(0.7192975, dtype=float32),
#   array(0.6091079, dtype=float32),
#   array(0.91154534, dtype=float32),
#   array(0.64399207, dtype=float32),
#   array(0.5819249, dtype=float32),
#   array(0.6780386, dtype=float32),
#   array(0.5407027, dtype=float32),
#   array(0.42883092, dtype=float32),
#   array(0.70356053, dtype=float32),
#   array(0.66928566, dtype=float32),
#   array(0.814385, dtype=float32),
#   array(0.87615913, dtype=float32),
#   array(1.0045012, dtype=float32),
#   array(0.4092423, dtype=float32),
#   array(0.620076, dtype=float32),
#   array(0.58718705, dtype=float32),
#   array(0.5638316, dtype=float32),
#   array(0.57894194, dtype=float32),
#   array(0.49709582, dtype=float32),
#   array(1.0032163, dtype=float32),
#   array(0.5462374, dtype=float32),
#   array(0.7497027, dtype=float32),
#   array(1.0703537, dtype=float32),
#   array(0.57637525, dtype=float32),
#   array(0.62347263, dtype=float32),
#   array(0.5351514, dtype=float32),
#   array(0.49435753, dtype=float32),
#   array(0.54399496, dtype=float32),
#   array(0.60168207, dtype=float32),
#   array(0.7545477, dtype=float32),
#   array(0.6903791, dtype=float32),
#   array(0.4101891, dtype=float32),
#   array(0.5462725, dtype=float32),
#   array(0.4936578, dtype=float32),
#   array(0.64325607, dtype=float32),
#   array(0.7580381, dtype=float32),
#   array(0.65101063, dtype=float32),
#   array(0.7721648, dtype=float32),
#   array(0.8732479, dtype=float32),
#   array(0.9597446, dtype=float32),
#   array(0.67910665, dtype=float32),
#   array(0.6206428, dtype=float32),
#   array(0.66822886, dtype=float32),
#   array(0.43966863, dtype=float32),
#   array(0.32472444, dtype=float32),
#   array(0.60094106, dtype=float32),
#   array(0.3485467, dtype=float32),
#   array(0.71784246, dtype=float32),
#   array(0.6914666, dtype=float32),
#   array(0.41752902, dtype=float32),
#   array(0.5827127, dtype=float32),
#   array(0.8602976, dtype=float32),
#   array(0.9116422, dtype=float32),
#   array(0.6580297, dtype=float32),
#   array(0.63200027, dtype=float32),
#   array(0.9081057, dtype=float32),
#   array(0.90351045, dtype=float32),
#   array(0.775893, dtype=float32),
#   array(0.8195686, dtype=float32),
#   array(0.9004978, dtype=float32),
#   array(1.0828477, dtype=float32),
#   array(0.6493558, dtype=float32),
#   array(0.7944971, dtype=float32),
#   array(0.48816538, dtype=float32),
#   array(0.543737, dtype=float32),
#   array(0.7495724, dtype=float32),
#   array(0.6289294, dtype=float32),
#   array(0.5851989, dtype=float32),
#   array(0.50452644, dtype=float32),
#   array(0.47024974, dtype=float32),
#   array(0.48077875, dtype=float32),
#   array(0.7621964, dtype=float32),
#   array(0.6436985, dtype=float32),
#   array(0.8691244, dtype=float32),
#   array(0.49391198, dtype=float32),
#   array(0.8251813, dtype=float32),
#   array(0.49806765, dtype=float32),
#   array(0.5499125, dtype=float32),
#   array(0.6436416, dtype=float32),
#   array(0.5556196, dtype=float32),
#   array(0.64656013, dtype=float32),
#   array(0.4692998, dtype=float32),
#   array(0.5825382, dtype=float32),
#   array(0.75163996, dtype=float32),
#   array(1.360593, dtype=float32),
#   array(0.6011025, dtype=float32),
#   array(0.69178945, dtype=float32),
#   array(0.6902019, dtype=float32),
#   array(0.91057247, dtype=float32),
#   array(0.6289735, dtype=float32),
#   array(1.2357832, dtype=float32),
#   array(0.7422767, dtype=float32),
#   array(0.6085683, dtype=float32),
#   array(0.6230446, dtype=float32),
#   array(0.6292323, dtype=float32),
#   array(0.7003573, dtype=float32),
#   array(0.6565574, dtype=float32),
#   array(0.8585109, dtype=float32),
#   array(1.3281548, dtype=float32),
#   array(0.73969257, dtype=float32),
#   array(0.43732408, dtype=float32),
#   array(1.1196233, dtype=float32),
#   array(0.5766533, dtype=float32),
#   array(0.5606537, dtype=float32),
#   array(0.5750776, dtype=float32),
#   array(0.74911684, dtype=float32),
#   array(0.6182237, dtype=float32),
#   array(0.39672136, dtype=float32),
#   array(0.5390751, dtype=float32),
#   array(0.4280284, dtype=float32),
#   array(0.7497428, dtype=float32),
#   array(0.62515104, dtype=float32),
#   array(0.53951824, dtype=float32),
#   array(0.6518542, dtype=float32),
#   array(0.5516255, dtype=float32),
#   array(0.48703945, dtype=float32),
#   array(0.45291388, dtype=float32),
#   array(0.45980844, dtype=float32),
#   array(0.8053801, dtype=float32),
#   array(0.8213022, dtype=float32),
#   array(0.2660546, dtype=float32),
#   array(0.60806894, dtype=float32),
#   array(0.7057054, dtype=float32),
#   array(0.40618256, dtype=float32),
#   array(0.58734167, dtype=float32),
#   array(0.520177, dtype=float32),
#   array(0.56978285, dtype=float32),
#   array(0.40387768, dtype=float32),
#   array(0.68612796, dtype=float32),
#   array(0.6101108, dtype=float32),
#   array(0.88067347, dtype=float32),
#   array(0.8732977, dtype=float32),
#   array(0.7390853, dtype=float32),
#   array(0.78477186, dtype=float32),
#   array(0.5261644, dtype=float32),
#   array(1.1598972, dtype=float32),
#   array(0.40536836, dtype=float32),
#   array(0.7358562, dtype=float32),
#   array(0.6007342, dtype=float32),
#   array(0.49025527, dtype=float32),
#   array(0.69737, dtype=float32),
#   array(0.33902317, dtype=float32),
#   array(0.44921434, dtype=float32),
#   array(0.7257318, dtype=float32),
#   array(0.52107215, dtype=float32),
#   array(0.75622433, dtype=float32),
#   array(0.6986499, dtype=float32),
#   array(0.8616764, dtype=float32),
#   array(0.5081506, dtype=float32),
#   array(0.6282288, dtype=float32),
#   array(0.5123559, dtype=float32),
#   array(0.60983866, dtype=float32),
#   array(0.57411695, dtype=float32),
#   array(1.4188023, dtype=float32),
#   array(0.5858377, dtype=float32),
#   array(0.7636312, dtype=float32),
#   array(0.8692147, dtype=float32),
#   array(0.41334596, dtype=float32),
#   array(0.42221186, dtype=float32),
#   array(0.65787417, dtype=float32),
#   array(0.6218629, dtype=float32),
#   array(0.49406314, dtype=float32),
#   array(0.5891266, dtype=float32),
#   array(0.513931, dtype=float32),
#   array(0.6601793, dtype=float32),
#   array(0.51344585, dtype=float32),
#   array(0.3666834, dtype=float32),
#   array(0.3218315, dtype=float32),
#   array(0.49476245, dtype=float32),
#   array(0.46589267, dtype=float32),
#   array(0.46679264, dtype=float32),
#   array(0.79979074, dtype=float32),
#   array(0.5234716, dtype=float32),
#   array(0.7696319, dtype=float32),
#   array(0.87229174, dtype=float32),
#   array(0.52764946, dtype=float32),
#   array(0.6760187, dtype=float32),
#   array(0.92616594, dtype=float32),
#   array(0.4152342, dtype=float32),
#   array(0.5230924, dtype=float32),
#   array(0.68474543, dtype=float32),
#   array(0.51732737, dtype=float32),
#   array(0.4342786, dtype=float32),
#   array(0.99469733, dtype=float32),
#   array(0.39835826, dtype=float32),
#   array(0.45160472, dtype=float32),
#   array(0.53547275, dtype=float32),
#   array(0.4339129, dtype=float32),
#   array(0.5844794, dtype=float32),
#   array(0.6332017, dtype=float32),
#   array(0.35583046, dtype=float32),
#   array(0.56882656, dtype=float32),
#   array(0.4569199, dtype=float32),
#   array(1.0927395, dtype=float32),
#   array(0.87881476, dtype=float32),
#   array(0.5809797, dtype=float32),
#   array(0.47067153, dtype=float32),
#   array(0.26301202, dtype=float32),
#   array(0.49639377, dtype=float32),
#   array(0.33059236, dtype=float32),
#   array(0.35658568, dtype=float32),
#   array(0.59154975, dtype=float32),
#   array(0.65898144, dtype=float32),
#   array(0.62668836, dtype=float32),
#   array(0.60042727, dtype=float32),
#   array(0.4464096, dtype=float32),
#   array(0.7157881, dtype=float32),
#   array(0.51552254, dtype=float32),
#   array(0.47254068, dtype=float32),
#   array(0.57808566, dtype=float32),
#   array(0.55876535, dtype=float32),
#   array(0.47911158, dtype=float32),
#   array(0.68289375, dtype=float32),
#   array(0.349858, dtype=float32),
#   array(0.4037064, dtype=float32),
#   array(0.4837522, dtype=float32),
#   array(0.79625356, dtype=float32),
#   array(0.59780943, dtype=float32),
#   array(0.44704175, dtype=float32),
#   array(0.67896444, dtype=float32),
#   array(0.58881944, dtype=float32),
#   array(0.44113132, dtype=float32),
#   array(0.6623002, dtype=float32),
#   array(0.7553955, dtype=float32),
#   array(0.79703534, dtype=float32),
#   array(0.51990604, dtype=float32),
#   array(0.59641534, dtype=float32),
#   array(0.7283705, dtype=float32),
#   array(0.76531625, dtype=float32),
#   array(0.81212157, dtype=float32),
#   array(0.5956733, dtype=float32),
#   array(0.82581496, dtype=float32),
#   array(0.9722268, dtype=float32),
#   array(0.4060221, dtype=float32),
#   array(0.49653715, dtype=float32),
#   array(0.7330654, dtype=float32),
#   array(0.40088373, dtype=float32),
#   array(0.6302463, dtype=float32),
#   array(0.6470145, dtype=float32),
#   array(0.81139815, dtype=float32),
#   array(0.536384, dtype=float32),
#   array(0.5724769, dtype=float32),
#   array(0.40992054, dtype=float32),
#   array(0.76201236, dtype=float32),
#   array(0.712346, dtype=float32),
#   array(0.5656078, dtype=float32),
#   array(0.7539953, dtype=float32),
#   array(0.7420736, dtype=float32),
#   array(0.6548702, dtype=float32),
#   array(0.7942414, dtype=float32),
#   array(0.53435826, dtype=float32),
#   array(0.45859948, dtype=float32),
#   array(0.70025, dtype=float32),
#   array(0.39384985, dtype=float32),
#   array(0.45492813, dtype=float32),
#   array(0.29875773, dtype=float32),
#   array(0.6769895, dtype=float32),
#   array(0.67640513, dtype=float32),
#   array(0.31951377, dtype=float32),
#   array(0.7187731, dtype=float32),
#   array(0.4454639, dtype=float32),
#   array(0.6221086, dtype=float32),
#   array(0.488868, dtype=float32),
#   array(0.43045998, dtype=float32),
#   array(0.5900247, dtype=float32),
#   array(0.5340461, dtype=float32),
#   array(0.82974714, dtype=float32),
#   array(0.607702, dtype=float32),
#   array(0.59621155, dtype=float32),
#   array(0.8217078, dtype=float32),
#   array(0.5758393, dtype=float32),
#   array(0.67633325, dtype=float32),
#   array(0.4544677, dtype=float32),
#   array(0.9012875, dtype=float32),
#   array(0.6654239, dtype=float32),
#   array(0.59129393, dtype=float32),
#   array(0.60784394, dtype=float32),
#   array(0.45377526, dtype=float32),
#   array(0.54807144, dtype=float32),
#   array(0.35613024, dtype=float32),
#   array(0.5747809, dtype=float32),
#   array(0.69513214, dtype=float32),
#   array(0.7368669, dtype=float32),
#   array(0.519972, dtype=float32),
#   array(0.60594475, dtype=float32),
#   array(0.40755954, dtype=float32),
#   array(0.61691785, dtype=float32),
#   array(0.46218222, dtype=float32),
#   array(0.3134893, dtype=float32),
#   array(0.3449211, dtype=float32),
#   array(0.58619726, dtype=float32),
#   array(0.65970606, dtype=float32),
#   array(0.47444108, dtype=float32),
#   array(0.65374166, dtype=float32),
#   array(0.45799524, dtype=float32),
#   array(0.85373485, dtype=float32),
#   array(0.8140737, dtype=float32),
#   array(0.6186551, dtype=float32),
#   array(0.4711931, dtype=float32),
#   array(0.35138693, dtype=float32),
#   array(0.8537443, dtype=float32),
#   array(0.87372285, dtype=float32),
#   array(0.44852626, dtype=float32),
#   array(0.5730015, dtype=float32),
#   array(0.6149053, dtype=float32),
#   array(0.45812055, dtype=float32),
#   array(0.78201324, dtype=float32),
#   array(0.6177415, dtype=float32),
#   array(0.5714743, dtype=float32),
#   array(0.32864875, dtype=float32),
#   array(0.9019729, dtype=float32),
#   array(0.7352772, dtype=float32),
#   array(0.4612536, dtype=float32),
#   array(0.56733036, dtype=float32),
#   array(0.28656864, dtype=float32),
#   array(0.62440664, dtype=float32),
#   array(0.30849805, dtype=float32),
#   array(0.78429085, dtype=float32),
#   array(0.37687942, dtype=float32),
#   array(1.0055013, dtype=float32),
#   array(0.5145192, dtype=float32),
#   array(0.7745005, dtype=float32),
#   array(0.6046244, dtype=float32),
#   array(0.6362338, dtype=float32),
#   array(0.60502255, dtype=float32),
#   array(0.64224845, dtype=float32),
#   array(0.59038174, dtype=float32),
#   array(0.60203815, dtype=float32),
#   array(0.41657695, dtype=float32),
#   array(0.29154012, dtype=float32),
#   array(0.59639424, dtype=float32),
#   array(0.48141196, dtype=float32),
#   array(0.5996635, dtype=float32),
#   array(0.3937083, dtype=float32),
#   array(0.5398395, dtype=float32),
#   array(1.0026243, dtype=float32),
#   array(0.59074724, dtype=float32),
#   array(0.2925516, dtype=float32),
#   array(0.3630881, dtype=float32),
#   array(0.7107472, dtype=float32),
#   array(0.3795806, dtype=float32),
#   array(0.5047237, dtype=float32),
#   array(0.6840717, dtype=float32),
#   array(0.5430738, dtype=float32),
#   array(0.53710294, dtype=float32),
#   array(0.7895096, dtype=float32),
#   array(0.42063242, dtype=float32),
#   array(0.71586394, dtype=float32),
#   array(0.39784107, dtype=float32),
#   array(0.83127254, dtype=float32),
#   array(0.88487273, dtype=float32),
#   array(0.6305077, dtype=float32),
#   array(0.8732681, dtype=float32),
#   array(0.514077, dtype=float32),
#   array(0.5130576, dtype=float32),
#   array(0.63697135, dtype=float32),
#   array(0.48534232, dtype=float32),
#   array(0.77504706, dtype=float32),
#   array(0.4784911, dtype=float32),
#   array(0.52969885, dtype=float32),
#   array(0.52160853, dtype=float32),
#   array(0.45393887, dtype=float32),
#   array(0.6795803, dtype=float32),
#   array(1.0606843, dtype=float32),
#   array(0.6301735, dtype=float32),
#   array(0.6700884, dtype=float32),
#   array(0.5486817, dtype=float32),
#   array(0.8761782, dtype=float32),
#   array(0.5017756, dtype=float32),
#   array(0.4831695, dtype=float32),
#   array(0.43157223, dtype=float32),
#   array(0.64001775, dtype=float32),
#   array(1.3916825, dtype=float32),
#   array(0.6502778, dtype=float32),
#   array(0.6387872, dtype=float32),
#   array(0.846414, dtype=float32),
#   array(0.59220845, dtype=float32),
#   array(0.743602, dtype=float32),
#   array(0.9314612, dtype=float32),
#   array(0.4439101, dtype=float32),
#   array(0.6919585, dtype=float32),
#   array(0.4827749, dtype=float32),
#   array(0.6956086, dtype=float32),
#   array(0.53856903, dtype=float32),
#   array(0.6600855, dtype=float32),
#   array(0.41478807, dtype=float32),
#   array(0.55668634, dtype=float32),
#   array(0.6902048, dtype=float32),
#   array(0.70854414, dtype=float32),
#   array(0.42029342, dtype=float32),
#   array(0.56857646, dtype=float32),
#   array(0.76666325, dtype=float32),
#   array(0.6361005, dtype=float32),
#   array(0.5970254, dtype=float32),
#   array(0.52876043, dtype=float32),
#   array(0.6099246, dtype=float32),
#   array(0.55414313, dtype=float32),
#   array(0.70901555, dtype=float32),
#   array(0.7746152, dtype=float32),
#   array(0.4702646, dtype=float32),
#   array(0.67638606, dtype=float32),
#   array(0.4262888, dtype=float32),
#   array(0.36985528, dtype=float32),
#   array(0.63752633, dtype=float32),
#   array(0.4877736, dtype=float32),
#   array(0.58513093, dtype=float32),
#   array(0.5002472, dtype=float32),
#   array(1.0057343, dtype=float32),
#   array(0.7883102, dtype=float32),
#   array(0.48813868, dtype=float32),
#   array(0.35275775, dtype=float32),
#   array(0.46330222, dtype=float32),
#   array(0.7022661, dtype=float32),
#   array(0.31978124, dtype=float32),
#   array(0.3843099, dtype=float32),
#   array(0.5229381, dtype=float32),
#   array(0.724835, dtype=float32),
#   array(0.8323329, dtype=float32),
#   array(0.42118558, dtype=float32),
#   array(0.5219881, dtype=float32),
#   array(0.7375568, dtype=float32),
#   array(0.6273081, dtype=float32),
#   array(0.6779087, dtype=float32),
#   array(0.60113454, dtype=float32),
#   array(0.46149638, dtype=float32),
#   array(0.47565332, dtype=float32),
#   array(0.45604467, dtype=float32),
#   array(0.3789638, dtype=float32),
#   array(0.5393544, dtype=float32),
#   array(0.51986575, dtype=float32),
#   array(0.48588312, dtype=float32),
#   array(0.59869474, dtype=float32),
#   array(0.44674218, dtype=float32),
#   array(0.5265852, dtype=float32),
#   array(0.30908114, dtype=float32),
#   array(0.73073864, dtype=float32),
#   array(0.8136042, dtype=float32),
#   array(0.39965573, dtype=float32),
#   array(0.21608792, dtype=float32),
#   array(0.7275934, dtype=float32),
#   array(0.54940134, dtype=float32),
#   array(0.44479465, dtype=float32),
#   array(0.692293, dtype=float32),
#   array(0.7109272, dtype=float32),
#   array(0.59545505, dtype=float32),
#   array(0.6477982, dtype=float32),
#   array(0.5770713, dtype=float32),
#   array(0.576216, dtype=float32),
#   array(0.37753028, dtype=float32),
#   array(0.7443516, dtype=float32),
#   array(0.55584306, dtype=float32),
#   array(0.5787549, dtype=float32),
#   array(0.4710488, dtype=float32),
#   array(0.57933563, dtype=float32),
#   array(0.714447, dtype=float32),
#   array(0.71097404, dtype=float32),
#   array(1.597251, dtype=float32),
#   array(0.6560762, dtype=float32),
#   array(0.7374993, dtype=float32),
#   array(0.30789202, dtype=float32),
#   array(0.49754187, dtype=float32),
#   array(0.5254971, dtype=float32),
#   array(0.4023532, dtype=float32),
#   array(0.3419667, dtype=float32),
#   array(0.48079222, dtype=float32),
#   array(0.7591828, dtype=float32),
#   array(0.5817692, dtype=float32),
#   array(0.22065605, dtype=float32),
#   array(0.5659548, dtype=float32),
#   array(0.45161763, dtype=float32),
#   array(0.76910204, dtype=float32),
#   array(0.5834919, dtype=float32),
#   array(0.6562638, dtype=float32),
#   array(0.46706855, dtype=float32),
#   array(0.49606204, dtype=float32),
#   array(0.5937554, dtype=float32),
#   array(0.69609755, dtype=float32),
#   array(0.64423543, dtype=float32),
#   array(0.8506048, dtype=float32),
#   array(1.0300835, dtype=float32),
#   array(0.86943084, dtype=float32),
#   array(0.794138, dtype=float32),
#   array(0.49610257, dtype=float32),
#   array(0.41910547, dtype=float32),
#   array(0.50948507, dtype=float32),
#   array(0.5334802, dtype=float32),
#   array(0.35983452, dtype=float32),
#   array(0.52401537, dtype=float32),
#   array(0.6872244, dtype=float32),
#   array(0.672494, dtype=float32),
#   array(0.3083663, dtype=float32),
#   array(0.7097899, dtype=float32),
#   array(0.64351845, dtype=float32),
#   array(0.65759367, dtype=float32),
#   array(0.54247946, dtype=float32),
#   array(0.55410016, dtype=float32),
#   array(0.56666136, dtype=float32),
#   array(0.7960449, dtype=float32),
#   array(0.4705971, dtype=float32),
#   array(0.78161836, dtype=float32),
#   array(0.49289784, dtype=float32),
#   array(0.54028416, dtype=float32),
#   array(0.62329745, dtype=float32),
#   array(0.47033358, dtype=float32),
#   array(0.49584487, dtype=float32),
#   array(0.43320316, dtype=float32),
#   array(0.58894813, dtype=float32),
#   array(0.80101377, dtype=float32),
#   array(0.7155971, dtype=float32),
#   array(0.31400433, dtype=float32),
#   array(0.37545106, dtype=float32),
#   array(0.49281782, dtype=float32),
#   array(0.86549765, dtype=float32),
#   array(0.6124462, dtype=float32),
#   array(0.7789951, dtype=float32),
#   array(0.79790485, dtype=float32),
#   array(0.75450927, dtype=float32),
#   array(0.83118963, dtype=float32),
#   array(0.4665055, dtype=float32),
#   array(1.2863827, dtype=float32),
#   array(0.42258334, dtype=float32),
#   array(1.0977181, dtype=float32),
#   array(0.44189784, dtype=float32),
#   array(0.5177161, dtype=float32),
#   array(0.43112522, dtype=float32),
#   array(0.93276644, dtype=float32),
#   array(0.57963973, dtype=float32),
#   array(0.7115262, dtype=float32),
#   array(0.42696008, dtype=float32),
#   array(0.5448511, dtype=float32),
#   array(0.6650931, dtype=float32),
#   array(0.62854296, dtype=float32),
#   array(0.5868795, dtype=float32),
#   array(0.54514635, dtype=float32),
#   array(0.341393, dtype=float32),
#   array(0.3916036, dtype=float32),
#   array(0.44306865, dtype=float32),
#   array(0.34478414, dtype=float32),
#   array(0.7798422, dtype=float32),
#   array(0.49114925, dtype=float32),
#   array(0.9066178, dtype=float32),
#   array(0.49228144, dtype=float32),
#   array(0.54133135, dtype=float32),
#   array(0.4645223, dtype=float32),
#   array(0.4164978, dtype=float32),
#   array(0.4534363, dtype=float32),
#   array(0.5376716, dtype=float32),
#   array(0.39322466, dtype=float32),
#   array(0.49641308, dtype=float32),
#   array(0.70509285, dtype=float32),
#   array(0.60747993, dtype=float32),
#   array(0.39435753, dtype=float32),
#   array(0.6724996, dtype=float32),
#   array(0.9566719, dtype=float32),
#   array(0.6742748, dtype=float32),
#   array(0.5088534, dtype=float32),
#   array(0.5810871, dtype=float32),
#   array(0.41514024, dtype=float32),
#   array(0.6236537, dtype=float32),
#   array(0.5654505, dtype=float32),
#   array(0.30369556, dtype=float32),
#   array(0.8075755, dtype=float32),
#   array(0.62277293, dtype=float32),
#   array(0.5383082, dtype=float32),
#   ...])

# %%
model_1_results = eval_model(model=model_1, data_loader=test_dataloader,
    loss_fn=loss_fn, accuracy_fn=accuracy_fn
)
model_1_results
# Out:
# {'model_name': 'FashionMNISTModelV1',
#  'model_loss': 0.45746350288391113,
#  'model_acc': 83.98562300319489}

# %% [markdown]
# # Building a Convolutional Neural Network

# %% [markdown]
# Alright, time to step things up a notch.
#
# It's time to create a [Convolutional Neural Network](https://en.wikipedia.org/wiki/Convolutional_neural_network) (CNN or ConvNet).
#
# CNN's are known for their capabilities to find patterns in visual data.
#
# And since we're dealing with visual data, let's see if using a CNN model can improve upon our baseline.
#
# The CNN model we're going to be using is known as TinyVGG from the [CNN Explainer](https://poloclub.github.io/cnn-explainer/) website.
#
# It follows the typical structure of a convolutional neural network:
#
# `Input layer -> [Convolutional layer -> activation layer -> pooling layer] -> Output layer`
#
# Where the contents of `[Convolutional layer -> activation layer -> pooling layer]` can be upscaled and repeated multiple times, depending on requirements.

# %% [markdown]
# ### What model should I use?
#
# > **Question:** Wait, you say CNN's are good for images, are there any other model types I should be aware of?
#
# Good question.
#
# This table is a good general guide for which model to use (though there are exceptions).
#
# | **Problem type** | **Model to use (generally)** | **Code example** |
# | ----- | ----- | ----- |
# | Structured data (Excel spreadsheets, row and column data) | Gradient boosted models, Random Forests, XGBoost | [`sklearn.ensemble`](https://scikit-learn.org/stable/modules/classes.html#module-sklearn.ensemble), [XGBoost library](https://xgboost.readthedocs.io/en/stable/) |
# | Unstructured data (images, audio, language) | Convolutional Neural Networks, Transformers | [`torchvision.models`](https://pytorch.org/vision/stable/models.html), [HuggingFace Transformers](https://huggingface.co/docs/transformers/index) |
#
# > **Note:** The table above is only for reference, the model you end up using will be highly dependant on the problem you're wor

# %%
# Setup device agnostic code
import torch
device = "cuda" if torch.cuda.is_available() else "cpu"
device

# %% [markdown]
# Let's create an example `nn.Conv2d()` with various parameters:
# * `in_channels` (int) - Number of channels in the input image.
# * `out_channels` (int) - Number of channels produced by the convolution.
# * `kernel_size` (int or tuple) - Size of the convolving kernel/filter.
# * `stride` (int or tuple, optional) - How big of a step the convolving kernel takes at a time. Default: 1.
# * `padding` (int, tuple, str) - Padding added to all four sides of input. Default: 0.
#
# ![example of going through the different parameters of a Conv2d layer](https://raw.githubusercontent.com/mrdbourke/pytorch-deep-learning/main/images/03-conv2d-layer.gif)

# %%
torch.manual_seed(42)

# Create sample batch of random numbers with same size as image batch
images = torch.randn(size=(32, 3, 64, 64)) # [batch_size, color_channels, height, width]
test_image = images[0] # get a single image for testing

# %%
torch.manual_seed(42)

# Create a convolutional layer with same dimensions as TinyVGG 
# (try changing any of the parameters and see what happens)
conv_layer = nn.Conv2d(in_channels=3,
                       out_channels=10,
                       kernel_size=3,
                       stride=1,
                       padding=0) # also try using "valid" or "same" here 

# Pass the data through the convolutional layer
conv_layer(test_image) # Note: If running PyTorch <1.11.0, this will error because of shape issues (nn.Conv.2d() expects a 4d tensor as input)

# %%
# Extra Ex : Play with kernal size and stride and see what happens to the shapes

# %%
# Create a convolutional neural network 
class FashionMNISTModelV2(nn.Module):
    """
    Model architecture copying TinyVGG from: 
    https://poloclub.github.io/cnn-explainer/
    """
    def __init__(self, input_shape: int, hidden_units: int, output_shape: int):
        super().__init__()
        self.block_1 = nn.Sequential(
            nn.Conv2d(in_channels=input_shape, 
                      out_channels=hidden_units, 
                      kernel_size=3, # how big is the square that's going over the image?
                      stride=1, # default
                      padding=1),# options = "valid" (no padding) or "same" (output has same shape as input) or int for specific number 
            nn.ReLU(),
            nn.Conv2d(in_channels=hidden_units, 
                      out_channels=hidden_units,
                      kernel_size=3,
                      stride=1,
                      padding=1),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2,
                         stride=2) # default stride value is same as kernel_size
        )
        self.block_2 = nn.Sequential(
            nn.Conv2d(hidden_units, hidden_units, 3, padding=1),
            nn.ReLU(),
            nn.Conv2d(hidden_units, hidden_units, 3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )
        self.classifier = nn.Sequential(
            nn.Flatten(),
            # Where did this in_features shape come from? 
            # It's because each layer of our network compresses and changes the shape of our inputs data.
            nn.Linear(in_features=hidden_units*7*7, 
                      out_features=output_shape)
        )
    
    def forward(self, x: torch.Tensor):
        x = self.block_1(x)
        # print(x.shape)
        x = self.block_2(x)
        # print(x.shape)
        x = self.classifier(x)
        # print(x.shape)
        return x

torch.manual_seed(42)
model_2 = FashionMNISTModelV2(input_shape=1, 
    hidden_units=10, 
    output_shape=len(class_names)).to(device)
model_2
# Out:
# FashionMNISTModelV2(
#   (block_1): Sequential(
#     (0): Conv2d(1, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (block_2): Sequential(
#     (0): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=490, out_features=10, bias=True)
#   )
# )

# %% [markdown]
# # What is pooling?

# %% [markdown]
# `nn.MaxPool2d()` is a function in PyTorch that performs 2D max pooling over an input signal. Max pooling is a form of down-sampling that reduces the spatial size of an input tensor while retaining important information about its features.
#
# Here's how `nn.MaxPool2d()` works:
#
# First, the input tensor is divided into non-overlapping rectangular regions of a specified size, called "pools". For example, if the input tensor has a shape of (batch_size, num_channels, height, width), and the pooling kernel size is set to (2, 2), then the input tensor will be divided into pools of size (2, 2) along the height and width dimensions.
#
# Next, the maximum value of each pool is computed, and the resulting values are placed into a new output tensor at the corresponding spatial location.
# ![image.png](attachment:fbc30a6b-b0a6-475a-9f76-fe36a526c0f7.png)!
#
# ![image.png](attachment:114286f3-5ae8-4d57-81fa-f353ec8dc047.png)!

# %%
import torch
import torch.nn as nn

# Create a random 2D tensor of shape (1, 1, 4, 4)
input_tensor = torch.rand(1, 1, 4, 4)

# Define a max pooling layer with a kernel size of (2, 2)
maxpool_layer = nn.MaxPool2d(kernel_size=(2, 2))

# Apply the max pooling layer to the input tensor
output_tensor = maxpool_layer(input_tensor)

# Print the input and output tensor shapes
print("Input shape:", input_tensor.shape)
print("Output shape:", output_tensor.shape)

# %%
# EX 12 Train and evaluate this model 
# When training convert output from logits like
    # # Do the forward pass
    # y_logit = model_2(X)
    # # Turn predictions from logits -> prediction probabilities -> predictions labels
    # y_pred = torch.softmax(y_logit, dim=1).argmax(dim=1)

# %%
# Also compare the results(accuracy) and the training time

# %%
# Import tqdm for progress bar
from tqdm.auto import tqdm

def train_model_cnn(model):
    # Set the seed and start the timer
    torch.manual_seed(42)
    train_time_start_on_cpu = timer()
    # Set the number of epochs (we'll keep this small for faster training times)
    epochs = 3
    loss_values_arr = []
    # Set the loss function and optimizer
    loss_fn = nn.CrossEntropyLoss()
    optimizer = torch.optim.SGD(model.parameters(), lr=0.1)
    # Create training and testing loop
    for epoch in tqdm(range(epochs)):
        print(f"Epoch: {epoch}\n-------")
        ### Training
        train_loss = 0
        # Add a loop to loop through training batches
        for batch, (X, y) in enumerate(train_dataloader):
            model.train()
            # 1. Forward pass
            y_pred_logits = model(X)
            # 2. Calculate loss (per batch)
            loss = loss_fn(y_pred_logits, y)
            loss_values_arr.append(loss.item())  # Append loss.item() instead of loss
            # 3. Optimizer zero grad
            optimizer.zero_grad()
            # 4. Loss backward
            loss.backward()
            # 5. Optimizer step
            optimizer.step()
            # Print out how many samples have been seen
            if batch % 400 == 0:
                print(f"Looked at {batch * len(X)}/{len(train_dataloader.dataset)} samples")

        # Divide total training loss by length of training dataloader (per batch)
        train_loss /= len(train_dataloader)

        ### Testing
        # Setup variables for accumulatively adding up loss and accuracy
        test_loss, test_acc = 0, 0
        model.eval()
        with torch.inference_mode():
            for X, y in test_dataloader:
                # 1. Forward pass
                test_pred_logits = model(X)

                # 2. Calculate loss (accumatively)
                test_loss += loss_fn(test_pred_logits, y) # accumulatively add up the loss per epoch

                # 3. Calculate accuracy
                # Convert logits to prediction probabilities and then to predicted labels
                test_pred_probs = torch.softmax(test_pred_logits, dim=1)
                test_pred_labels = test_pred_probs.argmax(dim=1)

                test_acc += accuracy_fn(y_true=y, y_pred=test_pred_labels)

            # Calculations on test metrics need to happen inside torch.inference_mode()
            # Divide total test loss by length of test dataloader (per batch)
            test_loss /= len(test_dataloader)

            # Divide total accuracy by length of test dataloader (per batch)
            test_acc /= len(test_dataloader)

        ## Print out what's happening
        print(f"\nTrain loss: {train_loss:.5f} | Test loss: {test_loss:.5f}, Test acc: {test_acc:.2f}%\n")

    # Calculate training time
    train_time_end_on_cpu = timer()
    total_train_time_model_0 = train_time_end_on_cpu - train_time_start_on_cpu
    print(f"Total training time: {total_train_time_model_0:.2f} seconds")

    return model, loss_values_arr

# Now, you can train the model using the defined function
trained_model, loss_values = train_model(model_2)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch: 0
# -------
# Looked at 0/60000 samples
# Looked at 12800/60000 samples
# Looked at 25600/60000 samples
# Looked at 38400/60000 samples
# Looked at 51200/60000 samples
#
# Train loss: 0.00000 | Test loss: 0.39599, Test acc: 86.01%
#
# Epoch: 1
# -------
# Looked at 0/60000 samples
# Looked at 12800/60000 samples
# Looked at 25600/60000 samples
# Looked at 38400/60000 samples
# Looked at 51200/60000 samples
#
# Train loss: 0.00000 | Test loss: 0.35612, Test acc: 86.89%
#
# Epoch: 2
# -------
# Looked at 0/60000 samples
# Looked at 12800/60000 samples
# Looked at 25600/60000 samples
# Looked at 38400/60000 samples
# Looked at 51200/60000 samples
#
# Train loss: 0.00000 | Test loss: 0.33301, Test acc: 88.16%
#
# Train time on None: 95.274 seconds

# %%
eval_model(model=trained_model, data_loader=test_dataloader,
    loss_fn=loss_fn, accuracy_fn=accuracy_fn
)
# Out:
# {'model_name': 'FashionMNISTModelV2',
#  'model_loss': 0.3330090641975403,
#  'model_acc': 88.15894568690096}

# %% [markdown]
# # Further reading
#
# https://goodboychan.github.io/python/datacamp/pytorch/deep_learning/2020/07/29/01-Convolutional-Neural-Networks-in-PyTorch.html
#
# https://towardsdatascience.com/visualizing-convolution-neural-networks-using-pytorch-3dfa8443e74e
