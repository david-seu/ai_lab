# %%
import matplotlib.pyplot as plt
from sklearn.datasets import make_circles
import torch
import torch.nn as nn
import pandas as pd

# %%
# Make 2000 samples
n_samples = 2000

# Create circles
X, y = make_circles(n_samples,
                    noise=0.05, # a little bit of noise to the dots
                    random_state=42) # keep random state so we get the same values

# %%
# Turn data into tensors
# Otherwise this causes issues with computations later on
X = torch.from_numpy(X).type(torch.float)
y = torch.from_numpy(y).type(torch.float)

# %%
print(f"Last 5 X features:\n{X[5:]}") #Wink wink numpy slicing
print(f"Last 5 y labels:\n{y[5:]}")
# Out:
# Last 5 X features:
# tensor([[-0.1930,  0.7703],
#         [ 1.0001, -0.3373],
#         [-0.1127, -0.8118],
#         ...,
#         [ 0.6222, -0.7182],
#         [-0.7904,  0.1368],
#         [ 0.5993,  0.5590]])
# Last 5 y labels:
# tensor([1., 0., 1.,  ..., 0., 1., 1.])

# %%
# Visualize with a plot
plt.scatter(x=X[:, 0],
            y=X[:, 1],
            c=y,
            cmap=plt.cm.RdYlBu)# plot the first feature against the second feature, colored by the target labels

# %%
import pandas as pd

circles = pd.DataFrame(X.numpy,  columns=["X1", "X2"])
circles.head
